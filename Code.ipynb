# %%
import streamlit as st
from diffusers import StableDiffusionPipeline
import torch

# Load model
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id).to("cuda")

st.title("Text-to-Image Generation with Stable Diffusion")

prompt = st.text_input("Enter your prompt:")
if prompt:
    image = pipe(prompt).images[0]
    st.image(image)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# 2024-10-11 18:06:53.472 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.954
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-10-11 18:06:53.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.959 Session state does not function when running a script without `streamlit run`
# 2024-10-11 18:06:53.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 18:06:53.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
